# %%
1+1
# Out:
# 2

# %%
x = 'Hello world'
print(x)
# Out:
# Hello world

# %% [markdown]
# #### This is a list
# * item 1
# * item 2
# * item 3

# %% [markdown]
# <img src='projects/My First Project/data-assets/image.png'>
